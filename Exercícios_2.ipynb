# %% [markdown]
# <a href="https://colab.research.google.com/github/Soccoll/Quarentena-Dados/blob/master/Exerc%C3%ADcios_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
filmes = pd.read_csv("https://raw.githubusercontent.com/alura-cursos/introducao-a-data-science/master/aula0/ml-latest-small/movies.csv")
filmes.columns = ["filmeId", "titulo", "generos"]

# %%
avaliacoes = pd.read_csv("https://github.com/alura-cursos/introducao-a-data-science/blob/master/aula0/ml-latest-small/ratings.csv?raw=true")
avaliacoes.columns = ["usuarioId", "filmeId", "nota", "momento"]
avaliacoes.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
filmes.head()
# Out:
#    filmeId  ...                                      generos
# 0        1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1        2  ...                   Adventure|Children|Fantasy
# 2        3  ...                               Comedy|Romance
# 3        4  ...                         Comedy|Drama|Romance
# 4        5  ...                                       Comedy
#
# [5 rows x 3 columns]

# %%
filmes["generos"].str.get_dummies('|').sum()
# Out:
# (no genres listed)      34
# Action                1828
# Adventure             1263
# Animation              611
# Children               664
# Comedy                3756
# Crime                 1199
# Documentary            440
# Drama                 4361
# Fantasy                779
# Film-Noir               87
# Horror                 978
# IMAX                   158
# Musical                334
# Mystery                573
# Romance               1596
# Sci-Fi                 980
# Thriller              1894
# War                    382
# Western                167
# dtype: int64

# %%
filmes["generos"].str.get_dummies('|').sum().sort_values(ascending=False)
# Out:
# Drama                 4361
# Comedy                3756
# Thriller              1894
# Action                1828
# Romance               1596
# Adventure             1263
# Crime                 1199
# Sci-Fi                 980
# Horror                 978
# Fantasy                779
# Children               664
# Animation              611
# Mystery                573
# Documentary            440
# War                    382
# Musical                334
# Western                167
# IMAX                   158
# Film-Noir               87
# (no genres listed)      34
# dtype: int64

# %%
filmes["generos"].str.get_dummies('|').sum().sort_values(ascending=False).plot()

# %%
filmes["generos"].str.get_dummies('|').sum().sort_values(ascending=False).plot(
    kind='pie', 
    title='Categorias de filmes e suas presenças relativas',
    figsize=(8,8))
plt.show ()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-a010ce25eb33> in <module>()
#       3     title='Categorias de filmes e suas presenças relativas',
#       4     figsize=(8,8))
# ----> 5 plt.show ()
#
# NameError: name 'plt' is not defined

# %%
filmes["generos"].str.get_dummies('|').sum().sort_values(ascending=False).plot(
    kind='bar', 
    title='Filmes por categoria',
    figsize=(8,8))
plt.show ()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-eb55d551b405> in <module>()
#       3     title='Filmes por categoria',
#       4     figsize=(8,8))
# ----> 5 plt.show ()
#
# NameError: name 'plt' is not defined

# %%
import seaborn as sns
sns.set_style("whitegrid")

filmes_por_genero = filmes["generos"].str.get_dummies('|').sum().sort_values(ascending=False)
plt.figure(figsize=(16,8))
sns.barplot(x=filmes_por_genero.index,
            y=filmes_por_genero.values,
            palette=sns.color_palette("BuGn_r", n_colors=len(filmes_por_genero) + 4))
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-28129bdfffba> in <module>()
#       3
#       4 filmes_por_genero = filmes["generos"].str.get_dummies('|').sum().sort_values(ascending=False)
# ----> 5 plt.figure(figsize=(16,8))
#       6 sns.barplot(x=filmes_por_genero.index,
#       7             y=filmes_por_genero.values,
#
# NameError: name 'plt' is not defined

# %%
import seaborn as sns

filmes_por_genero = filmes["generos"].str.get_dummies('|').sum().sort_values(ascending=False)
plt.figure(figsize=(8,8))
sns.barplot(x=filmes_por_genero.index,
            y=filmes_por_genero.values,
            palette=sns.color_palette("BuGn_r", n_colors=len(filmes_por_genero) + 4))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-eca6c5c4c001> in <module>()
#       2
#       3 filmes_por_genero = filmes["generos"].str.get_dummies('|').sum().sort_values(ascending=False)
# ----> 4 plt.figure(figsize=(8,8))
#       5 sns.barplot(x=filmes_por_genero.index,
#       6             y=filmes_por_genero.values,
#
# NameError: name 'plt' is not defined

# %%
filmes_com_media.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-0cb953fa0f95> in <module>()
# ----> 1 filmes_com_media.head()
#
# NameError: name 'filmes_com_media' is not defined

# %%
notas_do_filme_1 = avaliacoes.query("filmeId==1")["nota"]
print(notas_do_filme_1.mean())
notas_do_filme_1.plot(kind='hist')
# Out:
# 3.9209302325581397

# %%
notas_do_filme_1 = avaliacoes.query("filmeId==2")["nota"]
print(notas_do_filme_1.mean())
notas_do_filme_1.plot(kind='hist')
# Out:
# 3.4318181818181817

# %%
filmes_com_media.sort_values("nota", ascending=False)[2450:2500]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-cb55f0ff1364> in <module>()
# ----> 1 filmes_com_media.sort_values("nota", ascending=False)[2450:2500]
#
# NameError: name 'filmes_com_media' is not defined

# %%
def plot_filme(n):
  notas_do_filme = avaliacoes.query(f"filmeId=={n}")["nota"]
  notas_do_filme.plot(kind='hist')
  return notas_do_filme.describe()

# %%
#Mágico de Oz
plot_filme(919)
# Out:
# count    92.000000
# mean      3.880435
# std       1.025418
# min       1.000000
# 25%       3.000000
# 50%       4.000000
# 75%       5.000000
# max       5.000000
# Name: nota, dtype: float64

# %%
plot_filme(46578)
# Out:
# count    77.000000
# mean      3.883117
# std       0.842522
# min       1.000000
# 25%       3.500000
# 50%       4.000000
# 75%       4.500000
# max       5.000000
# Name: nota, dtype: float64

# %%
def plot_filme(n):
  notas_do_filme = avaliacoes.query(f"filmeId=={n}")["nota"]
  notas_do_filme.plot(kind='hist')
  plt.show()
  print('\n')
  notas_do_filme.plot.box()
  plt.show()
  return notas_do_filme.describe()

plot_filme(919)
# Out:
# count    92.000000
# mean      3.880435
# std       1.025418
# min       1.000000
# 25%       3.000000
# 50%       4.000000
# 75%       5.000000
# max       5.000000
# Name: nota, dtype: float64

# %%
plot_filme(46578)
# Out:
# count    77.000000
# mean      3.883117
# std       0.842522
# min       1.000000
# 25%       3.500000
# 50%       4.000000
# 75%       4.500000
# max       5.000000
# Name: nota, dtype: float64

# %%
sns.boxplot(data = avaliacoes.query("filmeId in [1,2,919,46578]"), x ="filmeId", y="nota")

# %% [markdown]
# Desafio 1 ok

# %%
import seaborn as sns
sns.set_style("whitegrid")

filmes_por_genero = filmes["generos"].str.get_dummies('|').sum().sort_values(ascending=False)
plt.figure(figsize=(16,8))
plt.xticks(rotation=44)
sns.barplot(x=filmes_por_genero.index,
            y=filmes_por_genero.values,
            palette=sns.color_palette("BuGn_r", n_colors=len(filmes_por_genero) + 4))
plt.show()

# %% [markdown]
# Desafio 2 do Paulo Silveira
# Encontar vários filmes com médias próximas e distribuições diferentes, use a função plot_filmes(n) para plotar.

# %%
filmes_com_media.sort_values("nota", ascending=False)[2600:2650]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-f578c43c51c2> in <module>()
# ----> 1 filmes_com_media.sort_values("nota", ascending=False)[2600:2650]
#
# NameError: name 'filmes_com_media' is not defined

# %%
#Faixa de filmes
filmes_com_media.sort_values("nota", ascending=False)[2600:2650]

#Filme: Incredibles, The (2004
plot_filme(8961)

#Filme: Dead Man Walking (1995)
plot_filme(36)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-e36ed5a6bbb2> in <module>()
# ----> 1 filmes_com_media.sort_values("nota", ascending=False)[2600:2650]
#       2
#       3 #Filme: Incredibles, The (2004
#       4 plot_filme(8961)
#       5
#
# NameError: name 'filmes_com_media' is not defined

# %% [markdown]
# Desafio 3 do Paulo Silveira
# Criar o boxplot dos 10 filmes com mais votos (não é com maior média, é com mais votos!). Não apenas plot mas também analise e tente tirar conclusões.

# %%
#Agrupando os 10 melhores filmes
top_10_filmes = avaliacoes.groupby('filmeId')['filmeId'].count().sort_values(ascending=False).head(10)

#Separando a base de avaliações para os 10 melhores filmes
top_10_filmes_avaliacoes = avaliacoes[avaliacoes['filmeId'].isin(top_10_filmes.index)]

#plotando o conjunto de BoxPlots
sns.boxplot(data=top_10_filmes_avaliacoes , x="filmeId", y="nota")

# Insights
# - 7 dos filmes mais votadas tiveram seu range de nota entre 4 e 5.
# - O Filme 480 apesar de receber nota máxima em algumas avaliações teve a maioria dos votos entre 3 e 4.

# %% [markdown]
# Desafio 4 do Guilherme Silveira
# Configurar a visualização do boxplot gerado pelo seaborn (último boxplot plotado na aula). Configurar o tamanho e colocar o nome dos filmes nos thicks.

# %%
sns.boxplot(data = avaliacoes.query("filmeId in [1,2,919,46578]"), x ="filmeId", y="nota")
graf.set_xticklabels(nome_filmes['titulo'], rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-48e969497c18> in <module>()
# ----> 1 sns.boxplot(data = avaliacoes.query("filmeId in [1,2,919,46578]"), x ="filmeId", y="nota")
#       2 graf.set_xticklabels(nome_filmes['titulo'], rotation=45)
#       3 plt.show()
#
# NameError: name 'sns' is not defined

# %%
nome_filmes = filmes[filmes['filmeId'].isin(top_10_filmes.index)]

plt.figure(figsize=(35, 6))
graf = sns.boxplot(data=top_10_filmes_avaliacoes , x="filmeId", y="nota")
graf.set_xticklabels(nome_filmes['titulo'], rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-6cfed4e7d316> in <module>()
#       1 nome_filmes = filmes[filmes['filmeId'].isin(top_10_filmes.index)]
#       2
# ----> 3 plt.figure(figsize=(35, 6))
#       4 graf = sns.boxplot(data=top_10_filmes_avaliacoes , x="filmeId", y="nota")
#       5 graf.set_xticklabels(nome_filmes['titulo'], rotation=45)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# Desafio 5 do Allan Spadini
# Calcular moda, média e mediana dos filmes. Explore filmes com notas mais próximas de 0.5, 3 e 5.

# %%
# Calculando as estatisticas:
estatistica = avaliacoes.groupby('filmeId').agg({
    'nota':[
            pd.Series.mode,
            'mean',
            'median'
            ] 
})
# Renomeando as colunas: 
estatistica.columns = ['moda', 'media', 'mediana']

# Unindo com a base de filmes mais qualificada:
filmes_com_estatistica = filmes_com_avaliacoes.join(estatistica, on='filmeId')

# Explorando os dados:
filmes_prox_05 = filmes_com_estatistica[filmes_com_estatistica['nota'].between(0.5,1)]
filmes_prox_3 = filmes_com_estatistica[filmes_com_estatistica['nota'].between(3,3.9)]
filmes_prox_5 = filmes_com_estatistica[filmes_com_estatistica['nota'].between(4.9,5)]

print("Filmes com valor proximo a 0.5: \n\n",filmes_prox_05.describe(), "\n\n Filmes com valor proximo a 3: \n\n", filmes_prox_3.describe(),"\n\n Filmes com valor proximo a 5: \n\n", filmes_prox_5.describe())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-9f835be2a019> in <module>()
#      10
#      11 # Unindo com a base de filmes mais qualificada:
# ---> 12 filmes_com_estatistica = filmes_com_avaliacoes.join(estatistica, on='filmeId')
#      13
#      14 # Explorando os dados:
#
# NameError: name 'filmes_com_avaliacoes' is not defined

# %% [markdown]
# Desafio 6 da Thais André
# Plotar o boxplot e o histograma um do lado do outro (na mesma figura ou em figuras distintas, mas um do lado do outro).

# %%
# Redefinição da função de plotagem para que faça o plot um ao lado do outro como pedido.
def plot_hist_boxplot(n):
  figure, axs = plt.subplots(1,2, figsize = (10,5))
  notas_do_filme = avaliacoes.query(f"filmeId=={n}")["nota"]
  notas_do_filme.plot(kind='hist', ax= axs[0]) 
  notas_do_filme.plot.box(ax= axs[1])
  plt.show()

plot_hist_boxplot(555)
